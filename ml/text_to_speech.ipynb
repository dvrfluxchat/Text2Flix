# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from scipy.io.wavfile import write as write_wav
from IPython.display import Audio
from pathlib import Path

# download and load all models
preload_models()
# Out:
# ...
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /home/kartik/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|██████████████████████████████████████| 88.9M/88.9M [00:08<00:00, 11.6MB/s]

# %%
text_prompt = """
[clears throat] Once upon a time, in a kingdom of COLORFUL plants and vibrant animals, there lived a playful LION named Larry.
"""
# generate audio from text

history_prompt = "v2/en_speaker_9"
audio_array = generate_audio(text_prompt, history_prompt=history_prompt)
file_name = f"coorg_{Path(history_prompt).name}.wav"
# save audio to disk
write_wav(file_name, SAMPLE_RATE, audio_array)
  
# # play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# List available 🐸TTS models and choose the first one
# model_name = TTS.list_models()[0]
# # Init TTS
# tts = TTS(model_name)
# Out:
# ...
# 100%|███████████████████████████████████████████| 29/29 [00:13<00:00,  2.10it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
generate_audio??

# %%
import librosa
librosa.get_duration(path=file_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 import librosa
# ----> 2 librosa.get_duration(path=file_name)
#
# File ~/work/jovian-hackathon/env/lib/python3.10/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~/work/jovian-hackathon/env/lib/python3.10/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
# ...
